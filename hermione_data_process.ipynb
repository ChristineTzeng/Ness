# %%
# draw results

# %%
rolling_frame = 50
steps = 2000
num_agents = 100
iterations = 20
frame_size = 1
env_path = ''
# file_name = 'hermione'
# sub_name = 'original/'
# sub_name = 'refined/'
logs_path = env_path + 'logs/'
figure_path = env_path + 'figures/'
# logs_path = env_path + 'logs/' + sub_name

# %%
import csv
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.3)

# %%
def count_line(file):
    with open(file) as csv_file:
        count_line = sum(1 for _ in csv_file)
        return count_line

# %%
# plot alive agents' obedience, health value, emotion
# process_data

# sim_setting = ['primitive', 'sanctioning', 'emotion', 'message', 'hermione']
sim_setting = ['sanctioning', 'hermione']

with open(logs_path + 'sum_agent.csv', 'a', newline = '') as csv_file:
    writer = csv.writer(csv_file, delimiter = ',')
    writer.writerow(['type', 'steps', 'infected','healthy', 'asymptomatic', 'mild', 'critical', 'deceased', 'vaccinated', 'home_quarantine', 'violation', 'compliance', 'robustness', 'stay_home', 'voluntarily_stay_home_infected', 'self_directed_emotion', 'other_directed_emotion', 'desire_satisfaction', 'total_number_infections', 'reward'])

for file_name in sim_setting:
    file_path = logs_path + file_name + '/' + file_name + '_agent.csv'
    with open(file_path) as csv_file:
        healthy_arr, asymptom_arr, symptom_arr, critical_arr, deceased_arr, infected_arr =  0, 0, 0, 0, 0, 0
        vaccinated, FQ, violated, complied, robustness, at_home, coerced, self_directed_emotion, other_directed_emotion = 0, 0, 0, 0, 0, 0, 0, 0, 0
        goal_satisfaction, infected_times, reward = 0, 0, 0
        count_lines = count_line(file_path)
        csv_reader = csv.reader(csv_file, delimiter = ',')
        last_iter, last_step, last_id = 0, 1, -1
        avg_healthy, avg_asymptom, avg_symptom, avg_critical, avg_deceased, avg_infected = [0 for i in range(int(steps/frame_size))], [0 for i in range(int(steps/frame_size))], [0 for i in range(int(steps/frame_size))], [0 for i in range(int(steps/frame_size))], [0 for i in range(int(steps/frame_size))], [0 for i in range(int(steps/frame_size))]
        avg_vaccinated, avg_FQ, avg_violated, avg_complied = [0 for i in range(int(steps/frame_size))],[0 for i in range(int(steps/frame_size))],[0 for i in range(int(steps/frame_size))],[0 for i in range(int(steps/frame_size))]
        avg_at_home, avg_coerced = [0 for i in range(int(steps/frame_size))],[0 for i in range(int(steps/frame_size))]
        avg_self_emotion, avg_other_emotion = [0 for i in range(int(steps/frame_size))],[0 for i in range(int(steps/frame_size))]
        avg_robustness, avg_goal_satisfaction, avg_infected_times = [0 for i in range(int(steps/frame_size))],[0 for i in range(int(steps/frame_size))],[0 for i in range(int(steps/frame_size))]
        avg_reward = [0 for i in range(int(steps/frame_size))]
        for row in csv_reader:
            last_idx = int((last_step - 1) / frame_size)
            if last_iter != int(row[0]) or last_idx != int((int(row[1]) - 1) / frame_size):
                
                avg_healthy[last_idx] += healthy_arr
                avg_asymptom[last_idx] += asymptom_arr
                avg_symptom[last_idx] += symptom_arr
                avg_critical[last_idx] += critical_arr
                avg_deceased[last_idx] += deceased_arr
                avg_infected[last_idx] += infected_arr
                
                avg_vaccinated[last_idx] += vaccinated
                avg_FQ[last_idx] += FQ
                avg_violated[last_idx] += violated
                avg_complied[last_idx] += complied
                
                avg_at_home[last_idx] += at_home
                avg_coerced[last_idx] += coerced
                
                avg_self_emotion[last_idx] += self_directed_emotion
                avg_other_emotion[last_idx] += other_directed_emotion
                
                avg_goal_satisfaction[last_idx] += goal_satisfaction
                avg_infected_times[last_idx] += infected_times
                avg_reward[last_idx] += reward
                
                healthy_arr, asymptom_arr, symptom_arr, critical_arr, deceased_arr, infected_arr =  0, 0, 0, 0, 0, 0
                vaccinated, FQ, violated, complied, at_home, coerced, self_directed_emotion, other_directed_emotion = 0, 0, 0, 0, 0, 0, 0, 0
                goal_satisfaction, infected_times, reward = 0, 0, 0

# self.iteration, self.schedule.steps, agent.unique_id, 
# agent.health, agent.infected_times, agent.reward, 
# agent.FQ_frames, agent.vaccinated, agent.vaccine_last,
# agent.intention, agent.last_action, agent.x, 
# agent.y, agent.self_directed_emotion, agent.other_directed_emotion
            
            # record the numer of each health state
            if row[3] == '0':
#             if row[3] in ('0', '1'):
                healthy_arr += 1
            elif row[3] == '1':
                asymptom_arr += 1
            elif row[3] == '2':
                symptom_arr += 1
            elif row[3] == '3':
                critical_arr += 1
            elif row[3] == '4':
                deceased_arr += 1
            
            # asymptomatic, symptomatic and critical are all infected
            if row[3] in ('1','2','3'):
#             if row[3] in ('2','3'):
                infected_arr += 1
            
            # number of vaccinated agents
            if row[7] == 'True':
                vaccinated += 1
            
            # infected and going out = compliance violation
            if row[3] in ('1','2','3') and row[10] in ('1','2','3'):
                violated += 1
            
            # infected and stay home = compliance
            if row[3] in ('1','2','3') and row[10] == '0':
                complied += 1
            
            if row[11] == '0':
                at_home += 1
                if row[9] != '0' or int(row[6]) == 0:
                    coerced += 1
                # number of home-quarantine
#                 elif int(row[6]) > 0:
                elif int(row[6]) > 0 and row[11] == '0':
                    FQ += 1
            
            if row[9] != row[10] or row[9] == '-1':
                goal_satisfaction += 0
            else:
                goal_satisfaction += 1
            
            # number of times being infected
            infected_times += int(row[4])
            
            reward += float(row[5])
            
            if file_name not in ('primitive', 'sanctioning', 'message'):
                self_directed_emotion += int(row[13])
                other_directed_emotion += int(row[14])

            if count_lines == csv_reader.line_num:
                avg_healthy[last_idx] += healthy_arr
                avg_asymptom[last_idx] += asymptom_arr
                avg_symptom[last_idx] += symptom_arr
                avg_critical[last_idx] += critical_arr
                avg_deceased[last_idx] += deceased_arr
                avg_infected[last_idx] += infected_arr
                
                avg_vaccinated[last_idx] += vaccinated
                avg_FQ[last_idx] += FQ
                avg_violated[last_idx] += violated
                avg_complied[last_idx] += complied
                
                avg_at_home[last_idx] += at_home
                avg_coerced[last_idx] += coerced
                
                avg_self_emotion[last_idx] += self_directed_emotion
                avg_other_emotion[last_idx] += other_directed_emotion
                
                avg_goal_satisfaction[last_idx] += goal_satisfaction
                avg_infected_times[last_idx] += infected_times
                avg_reward[last_idx] += reward

                for j in range(len(avg_healthy)):
                    avg_healthy[j] /= (iterations)
                    avg_asymptom[j] /= (iterations)
                    avg_symptom[j] /= (iterations)
                    avg_critical[j] /= (iterations)
                    avg_deceased[j] /= (iterations)
                    avg_infected[j] /= (iterations)
                    
                    avg_vaccinated[j] /= (iterations)
                    avg_FQ[j] /= (iterations)
                    
                    avg_robustness[j] = 1 if avg_complied[j] == 0 and avg_violated[j] == 0 else (avg_complied[j] / (avg_violated[j] + avg_complied[j]))
                    
                    avg_violated[j] /= (iterations)
                    avg_violated[j] = avg_violated[j] / avg_infected[j] if avg_infected[j] > 0 else 0
                    avg_complied[j] /= (iterations)
                    avg_complied[j] = avg_complied[j] / avg_infected[j] if avg_infected[j] > 0 else 1
                    
                    avg_at_home[j] /= (iterations)
                    avg_coerced[j] /= (iterations)
                    avg_coerced[j] /= (avg_healthy[j] + avg_infected[j]) if avg_coerced[j] > 0 else 0
                    
                    avg_self_emotion[j] /= (iterations * num_agents)
                    avg_other_emotion[j] /= (iterations * num_agents)
                    
                    avg_goal_satisfaction[j] /= (iterations * num_agents)
                    avg_infected_times[j] /= (iterations * num_agents)
                    avg_reward[j] /= (iterations * num_agents)
                    
            last_iter = int(row[0])
            last_step = int(row[1])

    with open(logs_path + 'sum_agent.csv', 'a', newline = '') as csv_file:
        writer = csv.writer(csv_file, delimiter = ',')
        for i in range(len(avg_healthy)):
            writer.writerow([file_name, i + 1, avg_infected[i], avg_healthy[i], avg_asymptom[i], avg_symptom[i], avg_critical[i], avg_deceased[i], avg_vaccinated[i], avg_FQ[i], avg_violated[i], avg_complied[i], avg_robustness[i], avg_at_home[i], avg_coerced[i], avg_self_emotion[i], avg_other_emotion[i], avg_goal_satisfaction[i], avg_infected_times[i], avg_reward[i]])

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
dataframe['infected'] = dataframe['infected'].rolling(rolling_frame).mean()
sns_plot = sns.lineplot(y=dataframe.infected, x=dataframe.steps, hue=dataframe.type, data=dataframe)
fig = sns_plot.get_figure()
fig.savefig(figure_path + "infected.pdf", bbox_inches='tight')

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
dataframe['healthy'] = dataframe['healthy'].rolling(rolling_frame).mean()
sns_plot = sns.lineplot(y=dataframe.healthy, x=dataframe.steps, hue=dataframe.type, data=dataframe)
fig = sns_plot.get_figure()
plt.legend([],[], frameon=False)
fig.savefig(figure_path + "healthy.pdf", bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\Softwares\anaconda\envs\noe\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'healthy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-5261c7f48af6> in <module>
#       1 dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
# ----> 2 dataframe['healthy'] = dataframe['healthy'].rolling(rolling_frame).mean()
#       3 sns_plot = sns.lineplot(y=dataframe.healthy, x=dataframe.steps, hue=dataframe.type, data=dataframe)
#       4 fig = sns_plot.get_figure()
#       5 plt.legend([],[], frameon=False)
#
# E:\Softwares\anaconda\envs\noe\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# E:\Softwares\anaconda\envs\noe\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'healthy'

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
# sns.scatterplot(y=dataframe.asymptomatic, x=dataframe.steps, hue=dataframe.type, data=dataframe)
dataframe['asymptomatic'] = dataframe['asymptomatic'].rolling(rolling_frame).mean()
sns_plot = sns.lineplot(y=dataframe.asymptomatic, x=dataframe.steps, hue=dataframe.type, data=dataframe)
fig = sns_plot.get_figure()
fig.savefig(figure_path + "asymptomatic.pdf", bbox_inches='tight')

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
dataframe['mild'] = dataframe['mild'].rolling(rolling_frame).mean()
sns_plot = sns.lineplot(y=dataframe.mild, x=dataframe.steps, hue=dataframe.type, data=dataframe)
fig = sns_plot.get_figure()
fig.savefig(figure_path + "mild.pdf", bbox_inches='tight')

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
dataframe['critical'] = dataframe['critical'].rolling(rolling_frame).mean()
sns_plot = sns.lineplot(y=dataframe.critical, x=dataframe.steps, hue=dataframe.type, data=dataframe)
fig = sns_plot.get_figure()
fig.savefig(figure_path + "critical.pdf", bbox_inches='tight')

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
sns_plot = sns.lineplot(y=dataframe.deceased, x=dataframe.steps, hue=dataframe.type, data=dataframe)
# sns.boxplot(x=dataframe.type, y=dataframe.deceased)
fig = sns_plot.get_figure()
plt.legend([],[], frameon=False)
fig.savefig(figure_path + "deceased.pdf", bbox_inches='tight')

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
dataframe['vaccinated'] = dataframe['vaccinated'].rolling(rolling_frame).mean()
sns_plot = sns.lineplot(y=dataframe.vaccinated, x=dataframe.steps, hue=dataframe.type, data=dataframe)
# sns.boxplot(x=dataframe.type, y=dataframe.vaccinated)
# sns.boxplot(y=dataframe.type, x=dataframe.vaccinated)
fig = sns_plot.get_figure()
plt.legend([],[], frameon=False)
fig.savefig(figure_path + "vaccinated.pdf", bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1fb34ab4de81> in <module>
# ----> 1 dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
#       2 dataframe['vaccinated'] = dataframe['vaccinated'].rolling(rolling_frame).mean()
#       3 sns_plot = sns.lineplot(y=dataframe.vaccinated, x=dataframe.steps, hue=dataframe.type, data=dataframe)
#       4 # sns.boxplot(x=dataframe.type, y=dataframe.vaccinated)
#       5 # sns.boxplot(y=dataframe.type, x=dataframe.vaccinated)
#
# E:\Softwares\anaconda\envs\noe\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# E:\Softwares\anaconda\envs\noe\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# E:\Softwares\anaconda\envs\noe\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# E:\Softwares\anaconda\envs\noe\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# E:\Softwares\anaconda\envs\noe\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# E:\Softwares\anaconda\envs\noe\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# E:\Softwares\anaconda\envs\noe\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'logs/sum_agent.csv'

# %%
# dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
# dataframe['violation'] = dataframe['violation'].rolling(rolling_frame).mean()
# sns_plot = sns.lineplot(y=dataframe.violation, x=dataframe.steps, hue=dataframe.type, data=dataframe)
# # sns.boxplot(x=dataframe.type, y=dataframe.violation)
# # sns.boxplot(y=dataframe.type, x=dataframe.violation)
# fig = sns_plot.get_figure()
# fig.savefig(figure_path + "violation.png")

# # VIOLATION / infetced

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
dataframe['isolation'] = dataframe['isolation'].rolling(rolling_frame).mean()
sns_plot = sns.lineplot(y=dataframe.isolation, x=dataframe.steps, hue=dataframe.type, data=dataframe)
# sns.boxplot(x=dataframe.type, y=dataframe.compliance)
# sns.boxplot(y=dataframe.type, x=dataframe.compliance)
fig = sns_plot.get_figure()
fig.savefig(figure_path + "compliance.pdf", bbox_inches='tight')

# compliance / infetced

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
dataframe['forced_quarantine'] = dataframe['forced_quarantine'].rolling(rolling_frame).mean()
sns_plot = sns.lineplot(y=dataframe.forced_quarantine, x=dataframe.steps, hue=dataframe.type, data=dataframe)
# sns.boxplot(x=dataframe.type, y=dataframe.home_quarantine)
# sns.boxplot(y=dataframe.type, x=dataframe.home_quarantine)
fig = sns_plot.get_figure()
plt.legend([],[], frameon=False)
fig.savefig(figure_path + "home_quarantine.pdf", bbox_inches='tight') 
# force stay home infected

# %%
# dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
# dataframe['stay_home'] = dataframe['stay_home'].rolling(rolling_frame).mean()
# sns_plot = sns.lineplot(y=dataframe.stay_home, x=dataframe.steps, hue=dataframe.type, data=dataframe)
# # sns.boxplot(x=dataframe.type, y=dataframe.stay_home)
# # sns.boxplot(y=dataframe.type, x=dataframe.stay_home)
# fig = sns_plot.get_figure()
# fig.savefig(figure_path + "stay_home.png")

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
dataframe['voluntarily_stay_home_infected'] = dataframe['voluntarily_stay_home_infected'].rolling(rolling_frame).mean()
sns_plot = sns.lineplot(y=dataframe.voluntarily_stay_home_infected, x=dataframe.steps, hue=dataframe.type, data=dataframe)
fig = sns_plot.get_figure()
fig.savefig(figure_path + "voluntarily_stay_home_infected.pdf", bbox_inches='tight')

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
# sns.lineplot(y=dataframe.self_directed_emotion, x=dataframe.steps, hue=dataframe.type, data=dataframe)
sns_plot = sns.violinplot(x=dataframe.type, y=dataframe.self_directed_emotion, data=dataframe, order = ['emotion', 'hermione'], cut = 0)
# sns.boxplot(x=dataframe.type, y=dataframe.self_directed_emotion)
# sns.boxplot(y=dataframe.type, x=dataframe.self_directed_emotion, order = ['noe', 'hermione'])
fig = sns_plot.get_figure()
fig.savefig(figure_path + "self_directed_emotion.pdf", bbox_inches='tight')

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
# sns.lineplot(y=dataframe.other_directed_emotion, x=dataframe.steps, hue=dataframe.type, data=dataframe)
sns_plot = sns.violinplot(x=dataframe.type, y=dataframe.other_directed_emotion, data=dataframe, order = ['emotion', 'hermione'], cut = 0)
# sns.boxplot(y=dataframe.type, x=dataframe.other_directed_emotion, order = ['noe', 'hermione'])
# sns.swarmplot(y=dataframe.type, x=dataframe.other_directed_emotion, order = ['noe', 'hermione'])
fig = sns_plot.get_figure()
fig.savefig(figure_path + "other_directed_emotion.pdf", bbox_inches='tight')

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
dataframe['desire_satisfaction'] = dataframe['desire_satisfaction'].rolling(rolling_frame).mean()
sns_plot = sns.lineplot(y=dataframe.desire_satisfaction, x=dataframe.steps, hue=dataframe.type, data=dataframe)
# sns.boxplot(y=dataframe.type, x=dataframe.goal_satisfaction)
fig = sns_plot.get_figure()
fig.savefig(figure_path + "desire_satisfaction.pdf", bbox_inches='tight')

# %%
dataframe = pd.read_csv(logs_path + 'sum_agent.csv', error_bad_lines = False)
# dataframe['total_number_infections'] = dataframe['total_number_infections'].rolling(rolling_frame).mean()
sns_plot = sns.lineplot(y=dataframe.total_number_infections, x=dataframe.steps, hue=dataframe.type, data=dataframe)
fig = sns_plot.get_figure()
plt.legend([],[], frameon=False)
fig.savefig(figure_path + "total_number_infections.pdf", bbox_inches='tight')
